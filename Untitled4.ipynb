# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
Emp_data=pd.read_csv("Dataset01-Employee_Attrition.csv")

# %%
Emp_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
Emp_data.shape
# Out:
# (14999, 10)

# %%
Emp_data.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
Emp_data.info
# Out:
# <bound method DataFrame.info of        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department  salary
# 0                          0      sales     low
# 1                          0      sales  medium
# 2                          0      sales  medium
# 3                          0      sales     low
# 4                          0      sales     low
# ...                      ...        ...     ...
# 14994                      0    support     low
# 14995                      0    support     low
# 14996                      0    support     low
# 14997                      0    support     low
# 14998                      0    support     low
#
# [14999 rows x 10 columns]>

# %%
Emp_data[Emp_data.duplicated()]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 396                  0.46             0.57               2
# 866                  0.41             0.46               2
# 1317                 0.37             0.51               2
# 1368                 0.41             0.52               2
# 1461                 0.42             0.53               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 396                     139                   3              0     1
# 866                     128                   3              0     1
# 1317                    127                   3              0     1
# 1368                    132                   3              0     1
# 1461                    142                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years  Department  salary
# 396                        0       sales     low
# 866                        0  accounting     low
# 1317                       0       sales  medium
# 1368                       0       RandD     low
# 1461                       0       sales     low
# ...                      ...         ...     ...
# 14994                      0     support     low
# 14995                      0     support     low
# 14996                      0     support     low
# 14997                      0     support     low
# 14998                      0     support     low
#
# [3008 rows x 10 columns]

# %%
Emp_data1=Emp_data.drop_duplicates()
Emp_data1.shape
# Out:
# (11991, 10)

# %%
#check for missing values
Emp_data1.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
Emp_data1.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
#data exploration and visualization
Emp_data1['left'].value_counts()
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %%
Emp_data1['left'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='left'>

# %%
Emp_data1['left'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
Emp_data1.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
#impact of salary on employee retention
pd.crosstab(Emp_data1.salary,Emp_data1.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
#distribution of each numerical feature
num_feature_list1= [f for f in Emp_data1.columns if Emp_data1.dtypes[f]=='float64']
num_feature_list1
# Out:
# ['satisfaction_level', 'last_evaluation']

# %%
num_feature_list2= [f for f in Emp_data1.columns if Emp_data1.dtypes[f]=='int64']
num_feature_list2
# Out:
# ['number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'left',
#  'promotion_last_5years']

# %%
list=['number_project','average_montly_hours','time_spend_company','Work_accident','promotion_last_5years','satisfaction_level','last_evaluation']

# %%
Emp_data1['number_project'].plot(kind='hist',bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
  Emp_data1['average_montly_hours'].plot(kind='hist',bins=6)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#feature engineering
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
Emp_data1['salary']=label_encoder.fit_transform(Emp_data1['salary'])
Emp_data1['Department']=label_encoder.fit_transform(Emp_data1['Department'])
# Out:
# /tmp/ipython-input-1050820704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Emp_data1['salary']=label_encoder.fit_transform(Emp_data1['salary'])
# /tmp/ipython-input-1050820704.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Emp_data1['Department']=label_encoder.fit_transform(Emp_data1['Department'])

# %%
Emp_data1.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# 2       2
# 3       1
# 4       1

# %%
x= Emp_data1.drop('left',axis=1)
y=Emp_data1['left'] #dependent->target column

# %%
x_train.head()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 6426                 0.86             0.56               5
# 288                  0.82             0.91               5
# 5051                 0.62             0.52               3
# 11132                0.43             0.74               4
# 3687                 0.85             0.79               3
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 6426                    141                   2              0
# 288                     232                   5              0
# 5051                    148                   3              0
# 11132                   129                   6              0
# 3687                    156                   3              0
#
#        promotion_last_5years  Department  salary
# 6426                       0           7       2
# 288                        0           9       1
# 5051                       0           7       2
# 11132                      0           3       2
# 3687                       0           7       2

# %%
#train-test ratio
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
std_scaler= StandardScaler()

# %%
xtrain_scaled=std_scaler.fit_transform(x_train)
xtest_scaled=std_scaler.fit_transform(x_test)

# %%
xtrain_scaled
xtest_scaled
# Out:
# array([[-2.29068564,  0.45275329,  1.87367809, ..., -0.12342962,
#          0.36594548, -0.58863423],
#        [ 0.43395807,  1.45856207,  0.16554443, ..., -0.12342962,
#          0.70927877,  1.01061097],
#        [ 0.72738123,  1.51772729,  0.16554443, ..., -0.12342962,
#          0.36594548, -0.58863423],
#        ...,
#        [ 0.72738123, -0.3163946 , -0.68852241, ..., -0.12342962,
#          0.36594548,  1.01061097],
#        [ 0.26628768,  1.57689251,  0.16554443, ..., -0.12342962,
#         -0.32072109, -0.58863423],
#        [ 0.05669971, -0.07973371, -0.68852241, ..., -0.12342962,
#          0.70927877, -0.58863423]])

# %%
#model development
from sklearn.ensemble import RandomForestClassifier

# %%
Random_forest_model= RandomForestClassifier()

# %%
#model training
Random_forest_model.fit(xtrain_scaled,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=Random_forest_model.predict(xtest_scaled)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print (cm)
# Out:
# [[1983   15]
#  [  53  348]]

# %%
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# <Axes: >

# %%
from sklearn.metrics import accuracy_score
model_accuracy= accuracy_score(y_test,y_pred)
print("Accuracy=",model_accuracy)
# Out:
# Accuracy= 0.9716548561900792

# %%
from sklearn.metrics import precision_score
model_precision= precision_score(y_test,y_pred)
print("precision=",model_precision)
# Out:
# precision= 0.9586776859504132

# %%
from sklearn.metrics import f1_score
f1_score= f1_score(y_test,y_pred)
print("f1=",f1_score)
# Out:
# f1= 0.9109947643979057

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1998
#            1       0.96      0.87      0.91       401
#
#     accuracy                           0.97      2399
#    macro avg       0.97      0.93      0.95      2399
# weighted avg       0.97      0.97      0.97      2399

# %%
#applying kfold cross validation
from sklearn.model_selection import cross_val_score
scores=cross_val_score(Random_forest_model,xtrain_scaled,y_train,cv=5,scoring='accuracy')

print("cv score=",scores)
# Out:
# cv score= [0.98801459 0.98228244 0.98488008 0.98592284 0.98748697]
